# %% [markdown]
# # Proxy Target Engineering

# %% [markdown]
# ## Import required libraries

# %%
import sys 
import os

sys.path.insert(0, os.path.abspath('C:/Users/dagic/OneDrive/Documents/KAIM/Week_4/credit-risk-model/src'))

print('Path set. Python will now look in:', os.path.abspath('C:/Users/dagic/OneDrive/Documents/KAIM/Week_4/credit-risk-model/src'))
# Out:
# Path set. Python will now look in: C:\Users\dagic\OneDrive\Documents\KAIM\Week_4\credit-risk-model\src

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import data_loader as ld
import plots as pl
from data_processing import ProxyTargetEngineer
import pandas as pd

# %%
df_processed = pd.read_csv("../data/processed/data_processed.csv")
df_processed.head()
# Out:
#    TransactionId  BatchId  AccountId  SubscriptionId  CustomerId  \
# 0          78150    46980       2490            3535        2584
# 1          75821    31755       3219            2366        2584
# 2          39888    60272       2713             996        2806
# 3          48738     1797       3351             974        3733
# 4          41364    48941       3219            2366        3733
#
#    CurrencyCode  CountryCode  ProviderId  ProductId  ProductCategory  ...  \
# 0             0          0.0           5          1                0  ...
# 1             0          0.0           3         19                2  ...
# 2             0          0.0           5          0                0  ...
# 3             0          0.0           0         11                8  ...
# 4             0          0.0           3         19                2  ...
#
#    Avg_Trans_Amount  Transaction_Count  Std_Trans_Amount TransactionHour  \
# ...

# %% [markdown]
# ### Feature Engineering

# %%
# Cell 2: Run proxy engineering pipeline step
engineer = ProxyTargetEngineer(n_clusters=3, random_state=42)

# %%
# Fit and generate target distribution labels
df_with_target = engineer.fit_transform(df_processed)
# Out:
# 2026-06-03 15:18:46,153 [INFO] Identified Cluster 2 as the High-Risk Proxy.

# %%
# Cell 3: Verify engineering output
print("--- Target Distribution Balance ---")
print(df_with_target['is_high_risk'].value_counts(normalize=True))
# Out:
# --- Target Distribution Balance ---
# is_high_risk
# 0    0.896134
# 1    0.103866
# Name: proportion, dtype: float64

# %%
print("\n--- Final Table Preview ---")
print(df_with_target[['CustomerId', 'Amount', 'is_high_risk']].head())
# Out:
# --- Final Table Preview ---
#    CustomerId    Amount  is_high_risk
# 0        2584 -0.139857             0
# 1        2584 -0.457536             0
# 2        2806 -0.295582             1
# 3        3733  1.752200             0
# 4        3733 -0.651880             0

# %%
# Cell 4: Save Deliverable out to disk
df_with_target.to_csv("../data/processed/data_with_proxy_target.csv", index=False)
print("\nDataset successfully exported with 'is_high_risk' column.")
# Out:
# Dataset successfully exported with 'is_high_risk' column.
